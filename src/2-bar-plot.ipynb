# %% [markdown]
# ### Exercise 2: Bar Plot with Colors

# %%
# TODO: Create a bar plot with the following data: categories = ['A', 'B', 'C', 'D'] and values = [5, 7, 3, 9].
# Use different colors for each bar and add a title to the plot.
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]

# Check if categories and values have the same length
if len(categories) != len(values):
    print("Error: categories and values must have the same length for plotting.")
else:
    # Create a bar plot
    plt.bar(categories, values)

    # Labeling the axes and the plot
    plt.xlabel('Categories')
    plt.ylabel('Values')
    plt.title('Bar Plot')

    # Show the plot
    plt.show()
